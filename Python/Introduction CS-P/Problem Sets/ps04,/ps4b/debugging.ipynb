# %%
## BUG 27.12.2020 10:42
## Output
self = <ps4b.CiphertextMessage object at 0x7ff63cb4f280>, shift = 26

    def apply_shift(self, shift):
        '''
        Applies the Caesar Cipher to self.message_text with the input shift.
        Creates a new string that is self.message_text shifted down the
        alphabet by some number of characters determined by the input shift
    
        shift (integer): the shift with which to encrypt the message.
        0 <= shift < 26
    
        Returns: the message text (string) in which every character is shifted
             down the alphabet by the input shift
        '''
        shift_dict = self.build_shift_dict(shift)
>       assert type(shift_dict) == dict
E       AssertionError

ps4b/ps4b.py:146: AssertionError
-------------------------------------------------------------------------------------------------------- Captured stdout call ---------------------------------------------------------------------------------------------------------
## Error
Error, Shift key must be an integer from 0 to 26 excluding 26

## Hypothesis
 The range of the shift is out of bound
## Experiment
    change range to 25
## Result

# %% [markdown]
# ## BUG 27.12.2020 10:50
# ## Output
# def test_ciphertext_decrypt_message(cipherTextObject, return_value, expected):
#         if expected:
# >           assert cipherTextObject.decrypt_message() == return_value
#
# ps4b/tests/test_ps4b.py:146:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = <ps4b.CiphertextMessage object at 0x7f71b0bdb4f0>
#
#     def decrypt_message(self):
#         '''
#         Decrypt self.message_text by trying every possible shift value
#         and find the "best" one. We will define "best" as the shift that
#         creates the maximum number of real words when we use apply_shift(shift)
#         on the message text. If s is the original shift value used to encrypt
#         the message, then we would expect 26 - s to be the best shift value
#         for decrypting it.
#
#         Note: if multiple shifts are equally good such that they all create
#         the maximum number of valid words, you may choose any of those shifts
#         (and their corresponding decrypted messages) to return
#
#         Returns: a tuple of the best shift value used to decrypt the message
#         and the decrypted message text using that shift value
#         '''
#         # initialize a list of possible decryptions as list_decryptions
#         list_decryptions = []
#         # loop through all 26 decryption shifts
#         for i in range(25):
#         #     store shift value in shift_value
#             shift_value = i+1
#         # Create a PlaintextMessage with current shift
#             print(self.apply_shift(shift_value))
#             currentMessage = Message(self.apply_shift(shift_value))
#         #     store decrypted message in decrypted_message
#             decrypted_message = currentMessage.get_message_text()
#         #     store real words in words_count
#             words_counter = currentMessage.get_valid_words
#         #     append a tuple of (words_count,(shift_value, decrypted_message)) in list_decryptions
#             list_decryptions.append((words_counter, (shift_value, decrypted_message)))
#         # sort list_decryptions
# >       list_decryptions.sort()
# E       TypeError: '<' not supported between instances of 'method' and 'method'
#
# ps4b/ps4b.py:264: TypeError
# -------------------------------------------------------------------------------------------------------- Captured stdout call ---------------------------------------------------------------------------------------------------------
# ifmmp
# hello
# gdkkn
# fcjjm
# ebiil
# dahhk
# czggj
# byffi
# axeeh
# zwddg
# yvccf
# xubbe
# wtaad
# vszzc
# uryyb
# tqxxa
# spwwz
# rovvy
# qnuux
# pmttw
# olssv
# nkrru
# mjqqt
# lipps
# khoor
#
# ## Error
# >       list_decryptions.sort()
# E       TypeError: '<' not supported between instances of 'method' and 'method'
#
# ## Hypothesis
# The sort() method called on list_decryptions is causing an error
# ## Experiment
#  comment out list_decryptions.sort() and print the contents of list_decryptions
# ## Result
# [(<bound method Message.get_valid_words of <__main__.Message object at 0x7f261d703d60>>,
# (1,
# 'ifmmp')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261d703550>>,
# (2,
# 'hello')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5a8c70>>,
# (3,
# 'gdkkn')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5a8dc0>>,
# (4,
# 'fcjjm')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5a8f10>>,
# (5,
# 'ebiil')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261d703d90>>,
# (6,
# 'dahhk')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0100>>,
# (7,
# 'czggj')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0220>>,
# (8,
# 'byffi')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0340>>,
# (9,
# 'axeeh')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0460>>,
# (10,
# 'zwddg')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0580>>,
# (11,
# 'yvccf')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b06a0>>,
# (12,
# 'xubbe')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b07c0>>,
# (13,
# 'wtaad')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b08e0>>,
# (14,
# 'vszzc')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0a00>>,
# (15,
# 'uryyb')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0b20>>,
# (16,
# 'tqxxa')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0c40>>,
# (17,
# 'spwwz')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0d60>>,
# (18,
# 'rovvy')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0e80>>,
# (19,
# 'qnuux')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c5b0fa0>>,
# (20,
# 'pmttw')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c634100>>,
# (21,
# 'olssv')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c634220>>,
# (22,
# 'nkrru')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c634340>>,
# (23,
# 'mjqqt')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c634460>>,
# (24,
# 'lipps')),
# (<bound method Message.get_valid_words of <__main__.Message object at 0x7f261c634580>>,
# (25,
# 'khoor'))]
# (1,
# 'ifmmp')
# (1,
# 'ifmmp')
# ## analysis
# the loop stores a reference to get_valid_word instead of a result in the form of an integer.
# ## experiment
# There was a funtion call missing, added () to change the value from a reference to a function call
# ## result
# [([], (1, 'ifmmp')),
# ([], (2, 'hello')),
# ([], (3, 'gdkkn')),
# ([], (4, 'fcjjm')),
# ([], (5, 'ebiil')),
# ([], (7, 'czggj')),
# ([], (8, 'byffi')),
# ([], (10, 'zwddg')),
# ([], (11, 'yvccf')),
# ([], (12, 'xubbe')),
# ([], (14, 'vszzc')),
# ([], (15, 'uryyb')),
# ([], (17, 'spwwz')),
# ([], (18, 'rovvy')),
# ([], (19, 'qnuux')),
# ([], (20, 'pmttw')),
# ([], (21, 'olssv')),
# ([], (22, 'nkrru')),
# ([], (23, 'mjqqt')),
# ([], (24, 'lipps')),
# ([], (25, 'khoor')),
# (['a'], (6, 'dahhk')),
# (['a'], (9, 'axeeh')),
# (['a'], (16, 'tqxxa')),
# (['a', 'a'], (13, 'wtaad'))]
# (1, 'ifmmp')
# ## analysis
# in Message.__init__, the function that appends words to the valid_words list iterates through charachters and not through words
# ## experiment
# split the argument text into a list and iterate through it
# ## results
# [(0, (0, 'khoor')),
# (0, (1, 'khoor')),
# (0, (2, 'lipps')),
# (0, (3, 'mjqqt')),
# (0, (4, 'nkrru')),
# (0, (5, 'olssv')),
# (0, (6, 'pmttw')),
# (0, (7, 'qnuux')),
# (0, (8, 'rovvy')),
# (0, (9, 'spwwz')),
# (0, (10, 'tqxxa')),
# (0, (11, 'uryyb')),
# (0, (12, 'vszzc')),
# (0, (13, 'wtaad')),
# (0, (14, 'xubbe')),
# (0, (15, 'yvccf')),
# (0, (16, 'zwddg')),
# (0, (17, 'axeeh')),
# (0, (18, 'byffi')),
# (0, (19, 'czggj')),
# (0, (20, 'dahhk')),
# (0, (21, 'ebiil')),
# (0, (22, 'fcjjm')),
# (0, (23, 'gdkkn')),
# (0, (25, 'ifmmp')),
# (1, (24, 'hello'))]

# %%
## BUG Date Hour
## Output
## Error
## Hypothesis
## Experiment
## Result

# %%
## BUG 27.12.2020 11:47
## Output
    def test_ciphertext_decrypt_message(cipherTextObject, return_value, expected):
        if expected:
>           assert cipherTextObject.decrypt_message() == return_value
E           AssertionError: assert (1, 'ifmmp') == (24, 'hello')
E             At index 0 diff: 1 != 24
E             Full diff:
E             - (24, 'hello')
E             + (1, 'ifmmp')

ps4b/tests/test_ps4b.py:149: AssertionError
----------------------------- Captured stdout call -----------------------------
(1, 'ifmmp')

## Error

## Hypothesis
The sort() method sorts list_decryptions in ascending order
## Experiment
change the flag reverse to True
## Result
