# %% [markdown]
# <h1> hello</h1>

# %%
# %lsmagic

# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi*(15*np.random.rand(N))**2 #0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha = 0.5)
plt.show()

# %%
# %%HTML
# <h1 style = "color: blue; font-size: 12em;">Hello!!</h1>
# Out:
# <h1 style = "color: blue; font-size: 12em;">Hello!!</h1>

# %%
# %%timeit 
square_events = [n*n for n in range(1000)]
# Out:
# 44.5 µs ± 1.69 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.randn(10,5))
df.head()
# Out:
#           0         1         2         3         4
# 0 -0.735211 -1.791167  1.555347  0.850783  2.299521
# 1 -0.610001 -0.833475  1.171728 -0.400503  0.236888
# 2  1.004700 -0.150388  0.541453  0.756340 -1.412865
# 3  0.386753  0.630170 -1.035048 -0.403303 -0.507050
# 4 -0.329312 -1.248533 -1.634281 -1.469358 -1.769569

# %%
def f(x):
    return x**2

x = np.linspace(-.10, .10)
y=x**2

fig = plt.figure()
ax = plt.gca()
ax.plot(x, y)

ax.plot(x, y)
ax.text(-0.1, round(-0.1**2, 3), '({}, {})'.format(-0.1, round((-0.1)**2, 3),))
ax.text(0.1, round(0.1**2, 3), '({}, {})'.format(0.1, round(0.1**2, 3)))
ax.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) 

ax.grid(True)
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_color('none')
ax.axis('equal')
# Out:
# (-0.11000000000000001,
#  0.11000000000000001,
#  -0.0004956268221574346,
#  0.01049979175343607)

# %%
fig = plt.figure()

# x = np.linspace(-np.pi, np.pi, 100)
# y = 2*np.sin(x)

ax = plt.gca()

ax.plot(x, y)
ax.grid(True)
ax.spines['left'].set_position('zero')
ax.spines['right'].set_color('none')
ax.spines['bottom'].set_position('zero')
ax.spines['top'].set_color('none')

plt.xlim(-np.pi,np.pi)

plt.savefig("CenterOriginMatplotlib01.png")
plt.show()

# %%
# %%markdown
# $f(x) =x^2$
# <br>
# $\frac{x}{2}$
# <br>
# $\int^0_2$
# Out:
# $f(x) =x^2$
# <br>
# $\frac{x}{2}$
# <br>
# $\int^0_2$
